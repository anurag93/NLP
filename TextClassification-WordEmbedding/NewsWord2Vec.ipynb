# %%
from google.colab import drive
drive.mount('/content/drive')
# !ln -s "/content/drive/My Drive/data" "/content/data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ln: failed to create symbolic link '/content/data/data': Function not implemented

# %%
import spacy
from spacy import displacy
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
import gensim
import nltk
from gensim.models import Word2Vec
import pandas as pd
from spacy import displacy

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# !python -m spacy download en
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
nlp = spacy.load("en")

# %%
doc1 = nlp(u'A strategy in the Affordable Care Act - new york times')

doc2 = nlp(u'Republicans’ 4-Step Plan to Repeal the Affordable Care Act - The New York Times')

for token in doc1:
    print(str(token.text), str(token.pos_))


for token in doc2:
    print(str(token.text), str(token.lemma_), str(token.pos_), str(token.dep_))
# Out:
# A DET
# strategy NOUN
# in ADP
# the DET
# Affordable PROPN
# Care PROPN
# Act PROPN
# - PUNCT
# new ADJ
# york NOUN
# times NOUN
# Republicans republican NOUN compound
# ’ ’ NUM compound
# 4-Step 4-step NUM compound
# Plan Plan PROPN ROOT
# to to PART aux
# Repeal repeal VERB xcomp
# the the DET det
# Affordable Affordable PROPN compound
# Care Care PROPN compound
# Act Act PROPN dobj
# - - PUNCT punct
# The the DET det
# New New PROPN compound
# York York PROPN compound
# Times Times PROPN appos

# %%
tree_pos = dict()
for token in doc1:
    if str(token.pos_)  not in tree_pos.keys():
        value = str(token.pos_)
        pos_value = list()
    else:
      
        pos_value = tree_pos[str(token.pos_)]
    if pos_value.__contains__(str(token.text)):
        continue
    pos_value.append(str(token.text))
    tree_pos[str(token.pos_)] = pos_value


for token in doc2:
    if str(token.pos_)  not in tree_pos.keys():
        value = str(token.pos_)
        pos_value = list()
    else:
        pos_value = tree_pos[str(token.pos_)]
    if pos_value.__contains__(str(token.text)):
        continue
    pos_value.append(str(token.text))
    tree_pos[str(token.pos_)] = pos_value
    
tree_pos
# Out:
# {'ADJ': ['new'],
#  'ADP': ['in'],
#  'DET': ['A', 'the', 'The'],
#  'NOUN': ['strategy', 'york', 'times', 'Republicans'],
#  'NUM': ['’', '4-Step'],
#  'PART': ['to'],
#  'PROPN': ['Affordable', 'Care', 'Act', 'Plan', 'New', 'York', 'Times'],
#  'PUNCT': ['-'],
#  'VERB': ['Repeal']}

# %%
articles = pd.read_csv(r'/content/data/articles1.csv', usecols=['content']).head(1000)
sentences = ''
data = []
article = articles['content']
for line in article:
  sentences = sentences + line

# %%
sentences
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for sentence in sent_tokenize(sentences):
    temp = []

    for word in word_tokenize(sentence):
        temp.append(word.lower())
    data.append(temp)

# %%
model = Word2Vec(data, min_count=1, size=100, window=10, sg=1)

# %%
print("Similarity between Republicans", model.most_similar('york'))
# Out:
# Similarity between Republicans [('new', 0.8682863712310791), ('jersey', 0.7796611785888672), ('times', 0.7696734070777893), ('neediest', 0.7254456877708435), ('reuters', 0.7118082642555237), ('magazine', 0.7106624841690063), ('square', 0.7062228918075562), ('archdiocese', 0.7002396583557129), ('guardian', 0.7001716494560242), ('beneficiary', 0.6954370737075806)]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
